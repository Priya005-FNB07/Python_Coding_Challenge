# %% [markdown]
# #List Methods and Slicing:

# %% [markdown]
# ##Contact Directory:

# %%
cust_details=['Magesh',9765409865,'magesh@gmail.com']

# %%
print(type(cust_details))
# Out:
# <class 'list'>

# %%
print(cust_details)
# Out:
# ['Magesh', 9765409865, 'magesh@gmail.com']

# %%
cust_details[0]
# Out:
# 'Magesh'

# %%
cust_details[1]='9834567210'

# %%
print(cust_details)
# Out:
# ['Magesh', '9834567210', 'magesh@gmail.com']

# %%
cust_details.pop()
# Out:
# 'magesh@gmail.com'

# %%
print(cust_details)
# Out:
# ['Magesh', '9834567210']

# %%
add=input('enter new mail:id:')
# Out:
# enter new mail:id:mageshanu@gmail.com

# %%
cust_details.append('mageshanu@gmail.com')

# %%
print(cust_details)
# Out:
# ['Magesh', '9834567210', 'mageshanu@gmail.com']

# %%
cust_details.sort()

# %%
print(cust_details)
# Out:
# ['9834567210', 'Magesh', 'mageshanu@gmail.com']
