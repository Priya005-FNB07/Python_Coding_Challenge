# %% [markdown]
# #Dictionary,Set,Frozenset:

# %% [markdown]
# ##Student Grades & Hobbies Tracker:

# %%
student_list={'Arun':'Grade B',
'Anu':'Grade A',
'Kanan':'Grade C',
'Yamini':'Grade A'}

# %%
print(student_list)
# Out:
# {'Arun': 'Grade B', 'Anu': 'Grade A', 'Kanan': 'Grade C', 'Yamini': 'Grade A'}

# %%
student_list.update({'Janu':'Grade B','Kiruba':'Grade C','Priya':'Grade A'})

# %%
print(student_list)
# Out:
# {'Arun': 'Grade B', 'Anu': 'Grade A', 'Kanan': 'Grade C', 'Yamini': 'Grade A', 'Janu': 'Grade B', 'Kiruba': 'Grade C', 'Priya': 'Grade A'}

# %%
Hobbies=input('enter your hobbies:')
# Out:
# enter your hobbies:'dance','reading','chess'

# %%
print(Hobbies)
# Out:
# 'dance','reading','chess'

# %%
Frozen_hobbies=frozenset(Hobbies)

# %%
print(Frozen_hobbies)
# Out:
# frozenset({'g', 'a', 'd', ',', 'r', 's', 'n', 'e', 'c', 'h', 'i', "'"})
