# %% [markdown]
# #Student Profile Creator:

# %%
student_name="Arun"
age=14
favourite_subject="Tamil","Maths","Biology"

# %%
print(student_name)
print(age)
print(favourite_subject)
# Out:
# Arun
# 14
# ('Tamil', 'Maths', 'Biology')
