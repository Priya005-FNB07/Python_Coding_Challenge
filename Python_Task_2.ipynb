# %% [markdown]
#  # Feedback Analyzer

# %%
Feedback = input("Enter your Feedback: ")
# Out:
# Enter your Feedback: Ram

# %%
print(Feedback)
# Out:
# Ram

# %%
s="data analyst job is very interesting because of will face many raw data"

# %%
print(len(s))
# Out:
# 71

# %%
print(s.count("data"))
# Out:
# 2

# %%
print(s[:5])
# Out:
# data

# %%
print(s[-5:])
# Out:
#  data

# %%
print(s[::-1])
# Out:
# atad war ynam ecaf lliw fo esuaceb gnitseretni yrev si boj tsylana atad
