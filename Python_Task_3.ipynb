# %% [markdown]
# #Tuple,Immutable vs Mutable,List Creation:

# %% [markdown]
# ##Retail Inventory Manager

# %%
fixed_product='mobile','smart phone','pen','paper','towel'

# %%
new='charger','light','pencil'

# %%
new_product=(fixed_product+new)

# %%
print(new_product)
# Out:
# ('mobile', 'smart phone', 'pen', 'paper', 'towel', 'charger', 'light', 'pencil')

# %%
new_product1=new_product

# %%
print(new_product1)
# Out:
# ('mobile', 'smart phone', 'pen', 'paper', 'towel', 'charger', 'light', 'pencil')

# %%
product=input("enter a new product:")
# Out:
# enter a new product:Scale

# %%
print(product)
# Out:
# Scale

# %%
new_product2=new_product1+(product,)

# %%
print(new_product2)
# Out:
# ('mobile', 'smart phone', 'pen', 'paper', 'towel', 'charger', 'light', 'pencil', 'Scale')

# %%
remove_product=input("enter a product index to remove:")
# Out:
# enter a product index to remove:3

# %%
print(remove_product)
# Out:
# 3

# %%
new_product2=list(new_product2)

# %%
new_product2.pop(3)
# Out:
# 'paper'

# %%
print(new_product2)
# Out:
# ['mobile', 'smart phone', 'pen', 'towel', 'charger', 'light', 'pencil', 'Scale']
